# %% [markdown]
# <a href="https://colab.research.google.com/github/2017710206255MN/Machine-Learning/blob/main/Week_2_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt 
import numpy as np

# Data
x = np.arange(0, 50, 0.1)
y = np.sin(x)

# Graph creation
plt.plot(x, y)

# Determine chart properties
plt.title("Sine Graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")

# Show graphics
plt.show()

# %%
# Data
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
sizes = np.random.randint(10, 300, 50)

# Graph creation
plt.scatter(x, y, c=colors, s=sizes)

# Determine chart properties
plt.title("Point Chart")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show graphics
plt.show()

# %%
# Data
data = np.random.randn(2500)

# Graph creation
plt.hist(data, bins=30)

# Determine chart properties
plt.title("Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")

# Show graphics
plt.show()

# %%
# Data
x = ['A', 'B', 'C', 'D', 'E']
y = np.random.randint(1, 10, 5)

# Graph creation
plt.bar(x, y)

# Determine chart properties
plt.title("Column Chart")
plt.xlabel("Categories")
plt.ylabel("Values")

# Show graphics
plt.show()

# %%
# Data
sizes = [30, 25, 15, 10, 5, 5]

# Graph creation
plt.pie(sizes)

# Determine chart properties
plt.title("Pie Chart")

# Show graphics
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# Data
x = np.arange(-5, 5, 0.25)
y = np.arange(-5, 5, 0.25)
x, y = np.meshgrid(x, y)
r = np.sqrt(x**2 + y**2)
z = np.sin(r)

# 3D graphics creation
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# plotting graphics
ax.plot_surface(x, y, z)

# Determine chart properties
ax.set_title("3D Graphics")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")

# Show
plt.show()
